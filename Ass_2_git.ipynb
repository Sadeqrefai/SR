# %%
# Git and GitHub Assignment 2 This notebook demonstrates basic Git operations using Google Colab and GitHub.
# Updated

# %%
def multiply_numbers(a, b):
    return a * b

print(multiply_numbers(3, 4))
# Out:
# 12

# %%
def divide_numbers(a, b):
    if b != 0:
        return a / b
    return "Cannot divide by zero"
